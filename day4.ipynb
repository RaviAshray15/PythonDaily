# %%
import random 
a = random.randint(0, 1)

if a == 0: 
    print("Heads")

else:
    print("Tails")

# %%
import random 

friends = ['Alice', 'Bob', 'Charlie', 'David', 'Emmanuel']

a = random.randint(0,4)

print(f"The person who have to pay the bill is: {friends[a]}")
